# %% [markdown]
# # Generate emissions paths
# Firstly we generate reasonable CO2 total emissions, based on the emissions in the SR1.5 database. Then we infill the other emissions from this.
# # CO2 pathway

# %%
import numpy as np
import pandas as pd
import pyam
import silicone.multiple_infillers as mi
import sys
sys.path.append("..")

# %%
from scripts.climate import climate_assessment
# Out:
# C:\Users\rlamboll\AppData\Local\Continuum\anaconda3\envs\iiasa-climate-3\lib\site-packages\openscm_runner\progress.py:5: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
sr15_em = pyam.IamDataFrame("../input/complete_sr15_emissions.csv").filter(region="World")
sr15_em.data
# Out:
# pyam - INFO: Running in a notebook, setting up a basic logging at level INFO
# pyam.core - INFO: Reading file ..\input\complete_sr15_emissions.csv
#                     model                scenario region          variable  \
# 0             AIM/CGE 2.0  ADVANCE_2020_1.5C-2100  World      Emissions|BC
# 1             AIM/CGE 2.0  ADVANCE_2020_1.5C-2100  World      Emissions|BC
# 2             AIM/CGE 2.0  ADVANCE_2020_1.5C-2100  World      Emissions|BC
# 3             AIM/CGE 2.0  ADVANCE_2020_1.5C-2100  World      Emissions|BC
# 4             AIM/CGE 2.0  ADVANCE_2020_1.5C-2100  World      Emissions|BC
# ...                   ...                     ...    ...               ...
# 245906  WITCH-GLOBIOM 4.4       CD-LINKS_NoPolicy  World  Emissions|Sulfur
# 245907  WITCH-GLOBIOM 4.4       CD-LINKS_NoPolicy  World  Emissions|Sulfur
# 245908  WITCH-GLOBIOM 4.4       CD-LINKS_NoPolicy  World  Emissions|Sulfur
# 245909  WITCH-GLOBIOM 4.4       CD-LINKS_NoPolicy  World  Emissions|Sulfur
# 245910  WITCH-GLOBIOM 4.4       CD-LINKS_NoPolicy  World  Emissions|Sulfur
#
#              unit  year      value
# 0        Mt BC/yr  2005   8.336700
# 1        Mt BC/yr  2010   7.640800
# 2        Mt BC/yr  2015   7.272400
# 3        Mt BC/yr  2020   7.075200
# 4        Mt BC/yr  2025   5.848600
# ...           ...   ...        ...
# 245906  Mt SO2/yr  2060  32.966164
# 245907  Mt SO2/yr  2070  32.053593
# 245908  Mt SO2/yr  2080  30.864629
# 245909  Mt SO2/yr  2090  29.142678
# 245910  Mt SO2/yr  2100  26.862799
#
# [245911 rows x 7 columns]

# %%
scenario = "SSP2-45"
model = "MESSAGE-GLOBIOM 1.0"

# %%
sr15_em_int = sr15_em.interpolate([2025, 2035, 2045, 2055, 2065, 2075, 2085, 2095])

# %%
co2tot = "Emissions|CO2"
co2afolu = "Emissions|CO2|AFOLU"
co2ei = "Emissions|CO2|Energy and Industrial Processes"
sr15_em_int.filter(year=2030, variable=co2tot).data.plot()
# Out:
# <AxesSubplot:>

# %%
sr15_em_int.filter(year=2035, variable=co2tot).data.plot()
# Out:
# <AxesSubplot:>

# %%
sr15_em_int.filter(year=2040, variable=co2tot).data.plot()
# Out:
# <AxesSubplot:>

# %%
ratios = sr15_em_int.filter(variable="*CO2").timeseries()
ratios["ratio"] = ratios[2030]/ratios[2020]
ratios
# Out:
#                                                                          2000  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          2001  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          2002  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          2003  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          2004  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                                2005  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  34018.8847
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  34018.8847
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr  34018.8847
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr  34018.8847
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  34018.8847
# ...                                                                             ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  32849.4366
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  32849.4366
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr  32849.4366
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr  32849.4366
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  32849.4366
#
#                                                                          2006  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          2007  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          2008  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          2009  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   NaN
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr   NaN
# ...                                                                       ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr   NaN
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr   NaN
#
#                                                                          ...  \
# model             scenario               region variable      unit       ...
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  ...
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  ...
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr  ...
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr  ...
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  ...
# ...                                                                      ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  ...
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  ...
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr  ...
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr  ...
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  ...
#
#                                                                                  2060  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -5258.956300
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  10980.700700
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr    858.718800
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   8049.938100
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -4686.084400
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  69738.376010
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   4908.629446
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr  14107.422830
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr  -2903.374517
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  71218.412870
#
#                                                                                  2065  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -6501.472800
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  15043.564500
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   1753.150700
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr  11011.765000
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -4963.426600
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  72553.656250
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   3364.317738
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr  12540.542705
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr  -4530.490594
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  73968.842420
#
#                                                                                  2070  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -7657.057400
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  12896.354100
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr    919.006700
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   9749.008100
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -6589.198100
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  75368.936490
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr   1820.006029
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr  10973.662580
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr  -6157.606671
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  76719.271970
#
#                                                                                  2075  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -8285.770600
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  12750.819800
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   1217.790600
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   9574.375900
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -5979.087300
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  77896.998290
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr    -44.898001
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   8401.755735
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr  -8573.250151
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  79198.740515
#
#                                                                                  2080  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -8418.985800
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  13166.037200
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   1595.512600
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr  10536.182400
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -6495.764700
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  80425.060090
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  -1909.802031
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   5829.848890
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr -10988.893630
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  81678.209060
#
#                                                                                  2085  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -9072.225100
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  12254.783600
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr    989.062900
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   9812.566500
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -6556.196000
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  81723.237275
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  -3855.960452
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   3602.123486
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr -12855.971460
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  82927.783935
#
#                                                                                  2090  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -9964.356400
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  10392.472500
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr   -915.766100
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   7374.920900
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -7435.738600
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  83021.414460
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  -5802.118874
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   1374.398081
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr -14723.049290
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  84177.358810
#
#                                                                                  2095  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -8276.809300
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   9320.362700
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr  -1491.757800
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   6544.351000
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -5373.701200
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  81363.027885
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  -7050.130820
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr   -295.263383
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr -14473.010350
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  82322.657750
#
#                                                                                  2100  \
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  -8611.382300
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr   7758.438200
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr  -2459.894600
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr   5286.630300
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  -5746.439300
# ...                                                                               ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  79704.641310
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  -8298.142767
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr  -1964.924847
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr -14222.971410
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  80467.956690
#
#                                                                             ratio
# model             scenario               region variable      unit
# AIM/CGE 2.0       ADVANCE_2020_1.5C-2100 World  Emissions|CO2 Mt CO2/yr  0.480011
#                   ADVANCE_2020_Med2C     World  Emissions|CO2 Mt CO2/yr  0.543255
#                   ADVANCE_2020_WB2C      World  Emissions|CO2 Mt CO2/yr  0.543425
#                   ADVANCE_2030_Med2C     World  Emissions|CO2 Mt CO2/yr  0.945143
#                   ADVANCE_2030_Price1.5C World  Emissions|CO2 Mt CO2/yr  0.936908
# ...                                                                           ...
# WITCH-GLOBIOM 4.4 CD-LINKS_NPi           World  Emissions|CO2 Mt CO2/yr  1.251842
#                   CD-LINKS_NPi2020_1000  World  Emissions|CO2 Mt CO2/yr  0.510759
#                   CD-LINKS_NPi2020_1600  World  Emissions|CO2 Mt CO2/yr  0.717518
#                   CD-LINKS_NPi2020_400   World  Emissions|CO2 Mt CO2/yr  0.379542
#                   CD-LINKS_NoPolicy      World  Emissions|CO2 Mt CO2/yr  1.229468
#
# [414 rows x 34 columns]

# %%
min(ratios.ratio)
# Out:
# 0.11855040813124396

# %%
max(ratios.ratio)
# Out:
# 1.3601769745833048

# %%
basis_scen = sr15_em_int.filter(model=model, scenario=scenario, year=[2010, 2015, 2020])

# %%
list(range(1, 4, 2))
# Out:
# [1, 3]

# %%
try:
    del all_scens
except NameError:
    pass
yeargap = 10
min_netz = 2040 # None of the scenarios meet net 0 by 2035 so this is the earliest round numb
max_grad = 5000
overshoots = [0, -5000, -10000]
for mod_2030 in np.arange(0.12, 1.32, 0.1):
    for net_zero in np.arange(min_netz, 2101, yeargap):
        for overshoot in overshoots:
            scen = basis_scen.filter(variable="*CO2").timeseries()
            scen[2030] = scen[2020] * mod_2030
            for year in range(2030 + yeargap, net_zero + 1, yeargap):
                scen[year] = scen[2030] * (net_zero - year) / (net_zero - 2030)
            for year in range(net_zero + yeargap, 2101, yeargap):
                scen[year] = max([overshoot, scen[year - yeargap].values - max_grad])
            scen = scen.reset_index()
            scen["scenario"] = f"2030fact{mod_2030}_nz{net_zero}_ov{overshoot}"
            try:
                all_scens = all_scens.append(scen)
            except NameError:
                all_scens = scen
all_scens = pyam.IamDataFrame(all_scens)

# %%
all_scens.plot()
# Out:
# pyam.plotting - INFO: >=13 labels, not applying legend
# <AxesSubplot:title={'center':'model: MESSAGE-GLOBIOM 1.0 - region: World - variable: Emissions|CO2'}, xlabel='Year', ylabel='Mt CO2/yr'>

# %% [markdown]
# # Break down CO2 total and infill non-CO2 emissions
# Break down CO2 total

# %%
co2_infiller = mi.SplitCollectionWithRemainderEmissions(sr15_em)
co2_breakdown = co2_infiller.infill_components(co2tot, [co2afolu], co2ei, all_scens, )

# %%
co2_breakdown.plot()
# Out:
# pyam.plotting - INFO: >=13 labels, not applying legend
# <AxesSubplot:title={'center':'model: MESSAGE-GLOBIOM 1.0 - region: World'}, xlabel='Year', ylabel='Mt CO2/yr'>

# %%
all_scens = all_scens.append(co2_breakdown)

# %%
# Infill the remaining emissions
required_variables_list = [
            "Emissions|BC",
            "Emissions|PFC|CF4",
            "Emissions|PFC|C2F6",
            "Emissions|PFC|C6F14",
            "Emissions|CH4",
            "Emissions|CO2|AFOLU",
            "Emissions|CO2|Energy and Industrial Processes",
            "Emissions|CO",
            "Emissions|HFC|HFC134a",
            "Emissions|HFC|HFC143a",
            "Emissions|HFC|HFC227ea",
            "Emissions|HFC|HFC23",
            "Emissions|HFC|HFC32",
            "Emissions|HFC|HFC43-10",
            "Emissions|HFC|HFC245ca",
            "Emissions|HFC|HFC125",
            "Emissions|N2O",
            "Emissions|NH3",
            "Emissions|NOx",
            "Emissions|OC",
            "Emissions|SF6",
            "Emissions|Sulfur",
            "Emissions|VOC",
        ]
other_infilled = mi.infill_all_required_variables(all_scens, sr15_em, [co2tot])
# Out:
# C:\Users\rlamboll\AppData\Local\Continuum\anaconda3\envs\iiasa-climate-3\lib\site-packages\silicone\multiple_infillers\infill_all_required_emissions_for_openscm.py:188: UserWarning: No data for ['Emissions|HFC|HFC245ca'], it will be infilled with 0s
#   warnings.warn(
# silicone.database_crunchers.constant_ratio - INFO: <class 'silicone.database_crunchers.constant_ratio.ConstantRatio'> won't use any information from the database
# Filling required variables:   0%|                                                                | 0/1 [00:00<?, ?it/s]silicone.database_crunchers.constant_ratio - WARNING: Note that the lead variable ['Emissions|CO2'] goes negative.
# Filling required variables: 100%|████████████████████████████████████████████████████████| 1/1 [00:00<00:00,  3.31it/s]
# Note that the lead variable ['Emissions|CO2'] goes negative.
# Filling required variables: 100%|██████████████████████████████████████████████████████| 22/22 [00:18<00:00,  1.20it/s]

# %%
#for variable in other_infiller.variable:
#    other_infiller.filter(variable=variable).plot()

# %%
sr15_em.filter(variable="*SF6").plot(legend=False)
# Out:
# <AxesSubplot:title={'center':'region: World - variable: Emissions|SF6'}, xlabel='Year', ylabel='kt SF6/yr'>

# %%
sr15_em.filter(variable="*C2F6").timeseries()
# Out:
#                                                                                                  2005  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.649467
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  2.070116
#
#                                                                                                  2010  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.456150
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  3.754667
#
#                                                                                                  2015  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.303700
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.936813
#
#                                                                                                  2020  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.151250
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  4.158928
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.158928
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.158928
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  4.158928
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  4.158928
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.158928
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  4.158928
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  4.922437
#
#                                                                                                  2025  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.205525
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  1.642299
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.642299
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.642299
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  1.642299
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  1.642299
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.642299
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  1.642299
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.875311
#
#                                                                                                  2030  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.259800
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.334045
#
#                                                                                                 2035  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.27395
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  1.06288
#
#                                                                                                  2040  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.288100
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.818667
#
#                                                                                                  2045  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.294675
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.628619
#
#                                                                                                  2050  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.301250
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.479899
#
#                                                                                                  2060  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.257600
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.293416
#
#                                                                                                  2070  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.253350
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.190967
#
#                                                                                                  2080  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.123450
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.130347
#
#                                                                                                  2090  \
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.121500
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.079087
#
#                                                                                                  2100
# model                       scenario                   region variable           unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|C2F6 kt C2F6/yr  2.081900
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534
#                             IMA15-Def                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534
#                             IMA15-Eff                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534
#                             IMA15-LiStCh               World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534
#                             IMA15-LoNCO2               World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534
#                             IMA15-Pop                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534
#                             IMA15-RenElec              World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534
#                             IMA15-TOT                  World  Emissions|PFC|C2F6 kt C2F6/yr  0.066534

# %%
sr15_em.filter(variable="*CF4").timeseries()
# Out:
#                                                                                                2005  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  11.60590
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr  10.56032
#
#                                                                                                2010  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.40915
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr  13.70864
#
#                                                                                                 2015  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.033325
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr  16.051769
#
#                                                                                                2020  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  15.65750
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr  12.77657
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr  12.77657
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr  12.77657
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr  12.77657
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr  12.77657
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr  12.77657
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr  12.77657
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr  14.47489
#
#                                                                                                 2025  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  15.821250
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   5.944234
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   5.944234
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   5.944234
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   5.944234
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   5.944234
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   5.944234
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   5.944234
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   6.806187
#
#                                                                                               2030  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  15.9850
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   5.2281
#
#                                                                                                 2035  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.116675
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   4.531747
#
#                                                                                                 2040  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.248350
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   3.817716
#
#                                                                                                 2045  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.336300
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   3.193105
#
#                                                                                                2050  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.42425
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   2.63672
#
#                                                                                                 2060  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.314800
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   2.026285
#
#                                                                                                 2070  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.231700
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   1.691359
#
#                                                                                                 2080  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.199900
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   1.425488
#
#                                                                                                2090  \
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.26100
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   1.17507
#
#                                                                                                 2100
# model                       scenario                   region variable          unit
# IEA World Energy Model 2017 Faster Transition Scenario World  Emissions|PFC|CF4 kt CF4/yr  16.097700
# IMAGE 3.0.1                 IMA15-AGInt                World  Emissions|PFC|CF4 kt CF4/yr   0.988551
#                             IMA15-Def                  World  Emissions|PFC|CF4 kt CF4/yr   0.988551
#                             IMA15-Eff                  World  Emissions|PFC|CF4 kt CF4/yr   0.988551
#                             IMA15-LiStCh               World  Emissions|PFC|CF4 kt CF4/yr   0.988551
#                             IMA15-LoNCO2               World  Emissions|PFC|CF4 kt CF4/yr   0.988551
#                             IMA15-Pop                  World  Emissions|PFC|CF4 kt CF4/yr   0.988551
#                             IMA15-RenElec              World  Emissions|PFC|CF4 kt CF4/yr   0.988551
#                             IMA15-TOT                  World  Emissions|PFC|CF4 kt CF4/yr   0.988551

# %%
other_infilled_df = other_infilled.data
other_infilled_df.variable = "Infilled|" + other_infilled_df.variable 
other_infilled_df
# Out:
#                      model                               scenario region  \
# 0      MESSAGE-GLOBIOM 1.0           2030fact0.12_nz2040_ov-10000  World
# 1      MESSAGE-GLOBIOM 1.0           2030fact0.12_nz2040_ov-10000  World
# 2      MESSAGE-GLOBIOM 1.0           2030fact0.12_nz2040_ov-10000  World
# 3      MESSAGE-GLOBIOM 1.0           2030fact0.12_nz2040_ov-10000  World
# 4      MESSAGE-GLOBIOM 1.0           2030fact0.12_nz2040_ov-10000  World
# ...                    ...                                    ...    ...
# 65515  MESSAGE-GLOBIOM 1.0  2030fact1.3200000000000003_nz2100_ov0  World
# 65516  MESSAGE-GLOBIOM 1.0  2030fact1.3200000000000003_nz2100_ov0  World
# 65517  MESSAGE-GLOBIOM 1.0  2030fact1.3200000000000003_nz2100_ov0  World
# 65518  MESSAGE-GLOBIOM 1.0  2030fact1.3200000000000003_nz2100_ov0  World
# 65519  MESSAGE-GLOBIOM 1.0  2030fact1.3200000000000003_nz2100_ov0  World
#
#                      variable       unit  year       value
# 0       Infilled|Emissions|BC   Mt BC/yr  2015    7.349054
# 1       Infilled|Emissions|BC   Mt BC/yr  2020    7.207993
# 2       Infilled|Emissions|BC   Mt BC/yr  2030    4.991303
# 3       Infilled|Emissions|BC   Mt BC/yr  2040    4.231053
# 4       Infilled|Emissions|BC   Mt BC/yr  2050    3.562387
# ...                       ...        ...   ...         ...
# 65515  Infilled|Emissions|VOC  Mt VOC/yr  2060  117.744568
# 65516  Infilled|Emissions|VOC  Mt VOC/yr  2070  109.814606
# 65517  Infilled|Emissions|VOC  Mt VOC/yr  2080  100.871468
# 65518  Infilled|Emissions|VOC  Mt VOC/yr  2090   92.054815
# 65519  Infilled|Emissions|VOC  Mt VOC/yr  2100   76.661333
#
# [65520 rows x 7 columns]

# %%
other_infilled_df = pyam.IamDataFrame(other_infilled_df)

# %% [markdown]
# # Calculate temperature data from this

# %%
outdir = "../output/v0/"
key_str = "v1"
magicc_temps = climate_assessment(
    other_infilled_df, 
    key_str,
    outdir,
    model_version=6
)
# Out:
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# <ipython-input-37-51be69998cbe> in <module>
#       1 outdir = "../output/v0/"
#       2 key_str = "v1"
# ----> 3 magicc_temps = climate_assessment(
#       4     other_infilled_df,
#       5     key_str,
#
# ~\PROVIDEcode\ProducingEmissionsPathways\notebooks\..\scripts\climate\__init__.py in climate_assessment(df, key_string, outdir, model, model_version, num_cfgs, test_run, scenario_batch_size, save_raw_output, probabilistic_file, magicc_extra_config, co2_and_non_co2_warming, prefix)
#     111         return None
#     112
# --> 113     climate_model_cfgs, climate_models_out_config = _get_model_configs_and_out_configs(
#     114         model=model,
#     115         model_version=model_version,
#
# ~\PROVIDEcode\ProducingEmissionsPathways\notebooks\..\scripts\climate\__init__.py in _get_model_configs_and_out_configs(model, model_version, probabilistic_file, extra_config, num_cfgs, co2_and_non_co2_warming)
#     397         if model_version is None:
#     398             model_version = DEFAULT_MAGICC_VERSION
# --> 399         magicc7_cfgs, magicc7_out_config = get_magicc7_configurations(
#     400             magicc_version=model_version,
#     401             magicc_probabilistic_file=probabilistic_file,
#
# ~\PROVIDEcode\ProducingEmissionsPathways\notebooks\..\scripts\climate\magicc7.py in get_magicc7_configurations(magicc_version, magicc_probabilistic_file, magicc_extra_config, num_cfgs, co2_and_non_co2_warming)
#      21     """
#      22
# ---> 23     if MAGICC7.get_version() != magicc_version:
#      24         # version strings for linux and windows might be different!
#      25         raise AssertionError(MAGICC7.get_version())
#
# ~\AppData\Local\Continuum\anaconda3\envs\iiasa-climate-3\lib\site-packages\openscm_runner\adapters\magicc7\magicc7.py in get_version(cls)
#     207             The MAGICC7 version id
#     208         """
# --> 209         return check_output([cls._executable(), "--version"]).decode("utf-8").strip()
#     210
#     211     @classmethod
#
# ~\AppData\Local\Continuum\anaconda3\envs\iiasa-climate-3\lib\subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     413         kwargs['input'] = empty
#     414
# --> 415     return run(*popenargs, stdout=PIPE, timeout=timeout, check=True,
#     416                **kwargs).stdout
#     417
#
# ~\AppData\Local\Continuum\anaconda3\envs\iiasa-climate-3\lib\subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     514         retcode = process.poll()
#     515         if check and retcode:
# --> 516             raise CalledProcessError(retcode, process.args,
#     517                                      output=stdout, stderr=stderr)
#     518     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['C:\\Program Files\\MAGICC6\\MAGICC6_4Download\\magicc6.exe', '--version']' returned non-zero exit status 3221225496.

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-6d1a2f3270ec> in <module>
# ----> 1 os.environ
#
# NameError: name 'os' is not defined

# %%
import os

# %%
os.environ["MAGICC_EXECUTABLE_7"] = "C:/Program Files/MAGICC6/MAGICC6_4Download/magicc6.exe"

# %%
os.environ["MAGICC_EXECUTABLE_7"]
# Out:
# 'C:\\Program Files\\MAGICC6\\MAGICC6_4Download\\magicc6.exe'
